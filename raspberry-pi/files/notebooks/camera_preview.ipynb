# %% [markdown]
# # Camera Preview
# In this lesson we will learn how to view the output of the camera attached to the Raspberry Pi.
#
# ## Setup
# Run the code cell below. This will setup the Raspberry Pi screen and import some helpers me need to use the camera in Python:

# %%
# RUN ME
# !big-display off
import os
from picamera2 import Picamera2, Preview, Platform

os.environ["DISPLAY"] = ":0"

# %% [markdown]
# # Camera
# To control our camera we use a Python class named `Picamera2`. We just need to create an instance of this class.
#
# _Run the cell below_

# %%
# RUN ME
cam = Picamera2()
# Out:
# Camera __init__ sequence did not complete.
# [0:43:08.818299307] [1774] ERROR Camera camera.cpp:702 Camera in Configured state trying acquire() requiring state Available
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/Documents/notebooks/.venv/lib/python3.13/site-packages/picamera2/picamera2.py:356, in Picamera2.__init__(self, camera_num, verbose_console, tuning, allocator)
#     355 try:
# --> 356     self._open_camera()
#     357     _log.debug(f"{self.camera_manager}")
#
# File ~/Documents/notebooks/.venv/lib/python3.13/site-packages/picamera2/picamera2.py:574, in Picamera2._open_camera(self)
#     573 # This now throws an error if it can't open the camera.
# --> 574 self.camera.acquire()
#     576 self.is_open = True
#
# RuntimeError: Failed to acquire camera: Device or resource busy
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 2
#       1 # RUN ME
# ----> 2 cam = Picamera2()
#
# File ~/Documents/notebooks/.venv/lib/python3.13/site-packages/picamera2/picamera2.py:368, in Picamera2.__init__(self, camera_num, verbose_console, tuning, allocator)
#     366 except Exception as e:
#     367     _log.error("Camera __init__ sequence did not complete.")
# --> 368     raise RuntimeError("Camera __init__ sequence did not complete.") from e
#     369 finally:
#     370     if tuning_file is not None:
#
# RuntimeError: Camera __init__ sequence did not complete.

# %% [markdown]
# > **Troubleshooting**:
# > Did the above cell succeed? If so ignore this...
# > If it failed with:
# > - `RuntimeError: Camera __init__ sequence did not complete.` then try:
# >   - Make sure a preview window is not showing on the Raspberry Pi screen, if it is use your remote desktop viewing program to close the window
# >   - In this website go to the Kernel menu at the top and click Restart Kernel
# >   - Try re-running all the code in this page up to this point
# > - `In use by another process` then try:
# >   - On the left where the file explorer is there is another tab labeled "Running Terminals and Kernels" (A circle icon with a square in it), click this tab
# >     - This tab lists all the notebooks you have open
# >     - For all the notebooks other than this one click the "X" button next it
# >     - Then try re-running the code above
# > - If you are still having problems and
#
# Now that we have a `Picamera2` instance we can configure it. We will our camera to show a preview image.
#
# - To do this we will call the `create_preview_configuration` function
#   - It takes a dictionary with the keys `size` and `format`
#   - Returns a configuration value
# - Then we will pass this configuration to the `configure` function to configure our camera
#
# _Run the cell below_

# %%
# RUN ME
config = cam.create_preview_configuration(main={
    "size": (224, 224),
    "format": "BGR888",
}, display="main")
cam.configure(config)
# Out:
# [0:43:10.271944497] [1774]  INFO Camera camera.cpp:1216 configuring streams: (0) 224x224-BGR888/sRGB (1) 640x480-SBGGR10_CSI2P/RAW
# [0:43:10.272521462] [1770]  INFO RPI vc4.cpp:620 Sensor: /base/soc/i2c0mux/i2c@1/imx219@10 - Selected sensor format: 640x480-SBGGR10_1X10/RAW - Selected unicam format: 640x480-pBAA/RAW

# %% [markdown]
# Now that we have configured our camera we can tell our camera to open the preview and start capturing images.
#
# - The `start_preview` function creates the preview image
# - The `start` function starts capturing images
#
# _Run the cell below_

# %%
# RUN ME
cam.start_preview(Preview.QT)
cam.start()
# Out:
# Exception in thread Thread-6 (listen):
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/threading.py", line 1043, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/threading.py", line 994, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/pi/Documents/notebooks/.venv/lib/python3.13/site-packages/picamera2/picamera2.py", line 124, in listen
#     callback()
#     ~~~~~~~~^^
#   File "/home/pi/Documents/notebooks/.venv/lib/python3.13/site-packages/picamera2/picamera2.py", line 141, in handle_request
#     self.cameras[req.cookie]._requests += [CompletedRequest(req, self.cameras[req.cookie])]
#                                            ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/pi/Documents/notebooks/.venv/lib/python3.13/site-packages/picamera2/request.py", line 101, in __init__
#     picam2.allocator.sync(self.picam2.allocator, buffer, False) for buffer in self.request.buffers.values()
#     ^^^^^^^^^^^^^^^^
# AttributeError: 'Picamera2' object has no attribute 'allocator'

# %% [markdown]
# If all goes well you should now see your camera on the screen on your Raspberry Pi!
#
# Once you are done viewing your camera run the code below to stop the preview and stop the camera:

# %%
# RUN ME
cam.stop_preview()
cam.stop()
